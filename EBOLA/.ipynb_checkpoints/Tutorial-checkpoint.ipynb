# %% [markdown]
# # Ebola model

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd

import Scripts\SimulatSEIR_expanded
import Scripts\HMMSEIR_expanded
import Scripts\MCMCSEIR_expanded
import Scripts\EMSEIR

import matplotlib.pyplot as plt

from scipy.stats import binom
# Out:
#   File "<ipython-input-5-3dd69615da1f>", line 4
#     import Scripts\SimulatSEIR_expanded
#                                        ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# ## Simulation from the Ebola model

# %% [markdown]
# We show how to simulate artificially some epidemics from the Ebola model. We set the parameters to the ones suggested in "Statistical Inference in a Stochastic Epidemic SEIR Model with Control Intervention: Ebola as a Case Study" by Phenyo E. Lekone and Bairbel F. Finkenstaidt.

# %% [markdown]
# ### Set the parameters

# %%
#parameters from Lekone and FInkenstadt 2006 Ebola paper
T = 212
N     = 5364501
beta  = 0.21
rho   = 1/5
gamma = 1/7

q_r = 0.2
t_star = 130

#eta_zero = np.array([5364500/N, 0, 1/N, 0])
eta_zero = np.array([5364500/5364501, 1/5364501, 0, 0]) #paper uses an even smaller I_0 than this
q = np.zeros((4,4))

q[1,2] = 291/316   #accounting for under-reporting as in the paper
q[2,3] = 236/316   #

SEIR_sim = SimulatSEIR_expanded.SEIR_expanded(N, beta, rho, gamma, q_r, t_star)

# %% [markdown]
# ### Simulate the epidemic and plot

# %%
np.random.seed(789)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5), dpi=200)

ax1.set_title("Total number of infectious")
ax2.set_title("New observed infectious")

for i in range(0, 10):
    # simulation1 is the true value of the compartments, y are our observations
    simulation1, y = SEIR_sim.Evolution(eta_zero, T, q)
    
    ax1.plot(simulation1[2,:], color = "red")
    
    ax2.plot(y[1,2,:], color = "orange")
    plt.axvline(130)

    # plt.plot(simulation1_norest[0,:], color = "green", linestyle = "--", label = r"No restr $X_t^S$")
    # plt.plot(simulation1_norest[1,:], color = "orange", linestyle = "--", label = r"No restr $X_t^E$")
    # plt.plot(simulation1_norest[2,:], color = "red", linestyle = "--", label = r"No restr $X_t^I$")
    # plt.plot(simulation1_norest[3,:], color = "blue", linestyle = "--", label = r"No restr $X_t^R$")
# plt.legend()
plt.show()

# %% [markdown]
# ## Multinomial approximation

# %% [markdown]
# Given the simulated data, we show how to use the multinomial approximation code to extract filtering and smoothing distributions with the corresponding 95%-credible intervals.

# %% [markdown]
# ### Set the parameters

# %%
HMM_expanded = HMMSEIR_expanded.HMM_approxSEIR_expanded(N, beta, rho, gamma, q, eta_zero, q_r, t_star)

# %% [markdown]
# ### Filtering distribution and credible intervals

# %%
pitt, _, pitt_expanded, _ = HMM_expanded.filtering(y)

# %% [markdown]
# Compute the credible intervals

# %%
p_I = np.zeros(T)
upper_I = np.zeros(T)
lower_I = np.zeros(T)
comp_ind = 1

alpha = 0.05

for t in range(T):

    p_I[t] = pitt[comp_ind,t] #smoothing distribution
    upper_I[t] = binom.ppf(1-alpha/2 , N, p_I[t]) 
    lower_I[t] = binom.ppf(alpha/2 , N, np.maximum(p_I[t],1e-12) ) #maximu to overcome bug in binom.ppf  
    
p_R = np.zeros(T)
upper_R = np.zeros(T)
lower_R = np.zeros(T)
comp_ind = 2

alpha = 0.05

for t in range(T):

    p_R[t] = pitt[comp_ind,t] #smoothing distribution
    upper_R[t] = binom.ppf(1-alpha/2 , N, p_R[t]) 
    lower_R[t] = binom.ppf(alpha/2 , N, np.maximum(p_R[t],1e-12) ) #maximu to overcome bug in binom.ppf

# %% [markdown]
# Plot the results

# %%
fig, ax = plt.subplots(1,1, figsize = (10, 5), dpi =100, sharey=True)

ax.plot(N*pitt[1,:], color = "orange", linestyle = "--", label = r"$\pi_{t|t}^E$")
ax.plot(N*pitt[2,:], color = "red", linestyle = "--", label = r"$\pi_{t|t}^I$")

ax.fill_between(range(T), lower_I, upper_I, alpha=0.2, color = "orange")
ax.fill_between(range(T), lower_R, upper_R, alpha=0.2, color = "red")

ax.plot(simulation1[1,:], color = "orange", label = r"$C_t/N$")
ax.plot(simulation1[2,:], color = "red", label = r"$D_t/N$")

ax.legend()

# %% [markdown]
# ### Smoothing distribution and credible intervals

# %%
pist, pist_expanded = HMM_expanded.smoothing(pitt_expanded, pitt)

# %% [markdown]
# Compute the credible intervals

# %%
p_I = np.zeros(T)
upper_I = np.zeros(T)
lower_I = np.zeros(T)
comp_ind = 1

alpha = 0.05

for t in range(T):

    p_I[t] = pist[comp_ind,t] #smoothing distribution
    upper_I[t] = binom.ppf(1-alpha/2 , N, p_I[t]) 
    lower_I[t] = binom.ppf(alpha/2 , N, np.maximum(p_I[t],1e-12) ) #maximu to overcome bug in binom.ppf  
    
p_R = np.zeros(T)
upper_R = np.zeros(T)
lower_R = np.zeros(T)
comp_ind = 2

alpha = 0.05

for t in range(T):

    p_R[t] = pist[comp_ind,t] #smoothing distribution
    upper_R[t] = binom.ppf(1-alpha/2 , N, p_R[t]) 
    lower_R[t] = binom.ppf(alpha/2 , N, np.maximum(p_R[t],1e-12) ) #maximu to overcome bug in binom.ppf

# %% [markdown]
# Plot the results (the smoothing distribution is closer to the true value of the compartment)

# %%
fig, ax = plt.subplots(1,1, figsize = (10, 5), dpi =100, sharey=True)

ax.plot(N*pist[1,:], color = "orange", linestyle = "--", label = r"$\pi_{t|t}^E$")
ax.plot(N*pist[2,:], color = "red", linestyle = "--", label = r"$\pi_{t|t}^I$")

ax.fill_between(range(T), lower_I, upper_I, alpha=0.2, color = "orange")
ax.fill_between(range(T), lower_R, upper_R, alpha=0.2, color = "red")

ax.plot(simulation1[1,:], color = "orange", label = r"$C_t/N$")
ax.plot(simulation1[2,:], color = "red", label = r"$D_t/N$")

ax.legend()

# %% [markdown]
# ## MCMC on sythetic data from the Ebola model

# %% [markdown]
# Run a Metropolis within Gibbs to estimate the parameters $\beta, \lambda, \gamma, \rho, q$

# %% [markdown]
# ### Set the parameters

# %%
seed = 321

#parameters from Lekone and FInkenstadt 2006 Ebola paper
T = 193
N     = 5364501
t_star = 130

# Set the initial conditions
np.random.seed(seed)
beta_0  = np.random.gamma(20, 1/100)        
rho_0   = np.random.gamma(20, 1/100)   
gamma_0 = np.random.gamma(20, 1/140) 

q_r_0 = np.random.gamma(2, 1/10)  

eta_zero_0 = np.array([5364500/5364501, 1/5364501, 0,0]) #paper uses an even smaller I_0 than this
x_0 = np.array([1, 1, 1, 1])

q_0 = np.zeros((4,4))
q_0[1,2] = np.random.uniform(0.5, 1)   #accounting for under-reporting as in the paper
q_0[2,3] = np.random.uniform(0.5, 1)   #

# Set the priors (this is the informative case)
beta_prior = np.array([ 20, 100])
rho_prior = np.array([  20, 100])
gamma_prior = np.array([20, 140])
q_r_prior = np.array([ 2, 10])

q_prior= np.array([1, 1])

# deprecated we do not learn the initial distribution, but potentially we could
eta_zero_prior = np.array([1, 1, 1, 1])


#Set the proposal
beta_proposal_variance = 0.03
rho_proposal_variance = 0.06
gamma_proposal_variance = 0.03
q_r_proposal_variance = 0.09

q_proposal_variance = 0.08

# %% [markdown]
# ### Run the MCMC
#
# it took around 10min on a 4 cores Intel(R) Core(TM) i7-7700HQ CPU @2.80GHz

# %%
# MCMC
MCMC = MCMCSEIR_expanded.MCMC_SEIR_expanded(N, t_star, beta_prior, rho_prior, gamma_prior, q_prior, q_r_prior, eta_zero_prior, beta_proposal_variance, rho_proposal_variance, gamma_proposal_variance, q_proposal_variance, q_r_proposal_variance)

np.random.seed(seed)

sample_size = 10000
beta_chain, rho_chain, gamma_chain, eta_zero_chain, q_chain, x_chain, q_r_chain = MCMC.posterior_sample( sample_size, y, beta_0, rho_0, gamma_0, eta_zero_0, x_0, q_0, q_r_0)
# Out:
# Iteration: 100
# Acceptance ratio beta: 0.25
# Acceptance ratio rho: 0.4
# Acceptance ratio gamma: 0.24
# Acceptance ratio q_r: 0.29
# Acceptance ratio q: 0.38
# Acceptance ratio eta: 0.0
# Iteration: 200
# Acceptance ratio beta: 0.27
# Acceptance ratio rho: 0.375
# Acceptance ratio gamma: 0.215
# Acceptance ratio q_r: 0.37
# Acceptance ratio q: 0.36
# Acceptance ratio eta: 0.0
# Iteration: 300
# Acceptance ratio beta: 0.2866666666666667
# Acceptance ratio rho: 0.37666666666666665
# Acceptance ratio gamma: 0.22333333333333333
# Acceptance ratio q_r: 0.36
# Acceptance ratio q: 0.36333333333333334
# Acceptance ratio eta: 0.0
# Iteration: 400
# Acceptance ratio beta: 0.2775
# Acceptance ratio rho: 0.3975
# Acceptance ratio gamma: 0.25
# Acceptance ratio q_r: 0.3275
# Acceptance ratio q: 0.3375
# Acceptance ratio eta: 0.0
# Iteration: 500
# Acceptance ratio beta: 0.278
# Acceptance ratio rho: 0.404
# Acceptance ratio gamma: 0.23
# Acceptance ratio q_r: 0.318
# Acceptance ratio q: 0.342
# Acceptance ratio eta: 0.0
# Iteration: 600
# Acceptance ratio beta: 0.28833333333333333
# Acceptance ratio rho: 0.4
# Acceptance ratio gamma: 0.23166666666666666
# Acceptance ratio q_r: 0.30833333333333335
# Acceptance ratio q: 0.33
# Acceptance ratio eta: 0.0
# Iteration: 700
# Acceptance ratio beta: 0.2785714285714286
# Acceptance ratio rho: 0.4
# Acceptance ratio gamma: 0.24571428571428572
# Acceptance ratio q_r: 0.31142857142857144
# Acceptance ratio q: 0.34
# Acceptance ratio eta: 0.0
# Iteration: 800
# Acceptance ratio beta: 0.28375
# Acceptance ratio rho: 0.40875
# Acceptance ratio gamma: 0.2525
# Acceptance ratio q_r: 0.3175
# Acceptance ratio q: 0.3475
# Acceptance ratio eta: 0.0
# Iteration: 900
# Acceptance ratio beta: 0.2833333333333333
# Acceptance ratio rho: 0.41555555555555557
# Acceptance ratio gamma: 0.24444444444444444
# Acceptance ratio q_r: 0.3055555555555556
# Acceptance ratio q: 0.34555555555555556
# Acceptance ratio eta: 0.0
# Iteration: 1000
# Acceptance ratio beta: 0.278
# Acceptance ratio rho: 0.408
# Acceptance ratio gamma: 0.239
# Acceptance ratio q_r: 0.307
# Acceptance ratio q: 0.343
# Acceptance ratio eta: 0.0
# Iteration: 1100
# Acceptance ratio beta: 0.2827272727272727
# Acceptance ratio rho: 0.4081818181818182
# Acceptance ratio gamma: 0.2509090909090909
# Acceptance ratio q_r: 0.3090909090909091
# Acceptance ratio q: 0.34363636363636363
# Acceptance ratio eta: 0.0
# Iteration: 1200
# Acceptance ratio beta: 0.2816666666666667
# Acceptance ratio rho: 0.3975
# Acceptance ratio gamma: 0.25166666666666665
# Acceptance ratio q_r: 0.32
# Acceptance ratio q: 0.34833333333333333
# Acceptance ratio eta: 0.0
# Iteration: 1300
# Acceptance ratio beta: 0.27307692307692305
# Acceptance ratio rho: 0.39692307692307693
# Acceptance ratio gamma: 0.24384615384615385
# Acceptance ratio q_r: 0.3192307692307692
# Acceptance ratio q: 0.3392307692307692
# Acceptance ratio eta: 0.0
# Iteration: 1400
# Acceptance ratio beta: 0.27071428571428574
# Acceptance ratio rho: 0.3914285714285714
# Acceptance ratio gamma: 0.2342857142857143
# Acceptance ratio q_r: 0.32857142857142857
# Acceptance ratio q: 0.32571428571428573
# Acceptance ratio eta: 0.0
# Iteration: 1500
# Acceptance ratio beta: 0.26866666666666666
# Acceptance ratio rho: 0.3893333333333333
# Acceptance ratio gamma: 0.232
# Acceptance ratio q_r: 0.324
# Acceptance ratio q: 0.324
# Acceptance ratio eta: 0.0
# Iteration: 1600
# Acceptance ratio beta: 0.26875
# Acceptance ratio rho: 0.38875
# Acceptance ratio gamma: 0.23
# Acceptance ratio q_r: 0.3225
# Acceptance ratio q: 0.3175
# Acceptance ratio eta: 0.0
# Iteration: 1700
# Acceptance ratio beta: 0.2688235294117647
# Acceptance ratio rho: 0.3847058823529412
# Acceptance ratio gamma: 0.23294117647058823
# Acceptance ratio q_r: 0.31882352941176473
# Acceptance ratio q: 0.3176470588235294
# Acceptance ratio eta: 0.0
# Iteration: 1800
# Acceptance ratio beta: 0.2738888888888889
# Acceptance ratio rho: 0.37833333333333335
# Acceptance ratio gamma: 0.235
# Acceptance ratio q_r: 0.32055555555555554
# Acceptance ratio q: 0.32
# Acceptance ratio eta: 0.0
# Iteration: 1900
# Acceptance ratio beta: 0.2794736842105263
# Acceptance ratio rho: 0.38263157894736843
# Acceptance ratio gamma: 0.2363157894736842
# Acceptance ratio q_r: 0.3273684210526316
# Acceptance ratio q: 0.3157894736842105
# Acceptance ratio eta: 0.0
# Iteration: 2000
# Acceptance ratio beta: 0.28
# Acceptance ratio rho: 0.382
# Acceptance ratio gamma: 0.237
# Acceptance ratio q_r: 0.3305
# Acceptance ratio q: 0.316
# Acceptance ratio eta: 0.0
# Iteration: 2100
# Acceptance ratio beta: 0.2780952380952381
# Acceptance ratio rho: 0.37857142857142856
# Acceptance ratio gamma: 0.2357142857142857
# Acceptance ratio q_r: 0.3323809523809524
# Acceptance ratio q: 0.3161904761904762
# Acceptance ratio eta: 0.0
# Iteration: 2200
# Acceptance ratio beta: 0.275
# Acceptance ratio rho: 0.37772727272727274
# Acceptance ratio gamma: 0.2359090909090909
# Acceptance ratio q_r: 0.33045454545454545
# Acceptance ratio q: 0.315
# Acceptance ratio eta: 0.0
# Iteration: 2300
# Acceptance ratio beta: 0.27217391304347827
# Acceptance ratio rho: 0.38217391304347825
# Acceptance ratio gamma: 0.23130434782608697
# Acceptance ratio q_r: 0.33043478260869563
# Acceptance ratio q: 0.31217391304347825
# Acceptance ratio eta: 0.0
# Iteration: 2400
# Acceptance ratio beta: 0.27416666666666667
# Acceptance ratio rho: 0.38
# Acceptance ratio gamma: 0.23666666666666666
# Acceptance ratio q_r: 0.3358333333333333
# Acceptance ratio q: 0.31666666666666665
# Acceptance ratio eta: 0.0
# Iteration: 2500
# Acceptance ratio beta: 0.2768
# Acceptance ratio rho: 0.38
# Acceptance ratio gamma: 0.2372
# Acceptance ratio q_r: 0.3364
# Acceptance ratio q: 0.322
# Acceptance ratio eta: 0.0
# Iteration: 2600
# Acceptance ratio beta: 0.27807692307692305
# Acceptance ratio rho: 0.3776923076923077
# Acceptance ratio gamma: 0.23615384615384616
# Acceptance ratio q_r: 0.3392307692307692
# Acceptance ratio q: 0.3230769230769231
# Acceptance ratio eta: 0.0
# Iteration: 2700
# Acceptance ratio beta: 0.27925925925925926
# Acceptance ratio rho: 0.37925925925925924
# Acceptance ratio gamma: 0.2374074074074074
# Acceptance ratio q_r: 0.3351851851851852
# Acceptance ratio q: 0.32592592592592595
# Acceptance ratio eta: 0.0
# Iteration: 2800
# Acceptance ratio beta: 0.27535714285714286
# Acceptance ratio rho: 0.3782142857142857
# Acceptance ratio gamma: 0.23607142857142857
# Acceptance ratio q_r: 0.3357142857142857
# Acceptance ratio q: 0.325
# Acceptance ratio eta: 0.0
# Iteration: 2900
# Acceptance ratio beta: 0.27586206896551724
# Acceptance ratio rho: 0.37689655172413794
# Acceptance ratio gamma: 0.23793103448275862
# Acceptance ratio q_r: 0.3368965517241379
# Acceptance ratio q: 0.32448275862068965
# Acceptance ratio eta: 0.0
# Iteration: 3000
# Acceptance ratio beta: 0.274
# Acceptance ratio rho: 0.37866666666666665
# Acceptance ratio gamma: 0.23733333333333334
# Acceptance ratio q_r: 0.333
# Acceptance ratio q: 0.322
# Acceptance ratio eta: 0.0
# Iteration: 3100
# Acceptance ratio beta: 0.27129032258064517
# Acceptance ratio rho: 0.3793548387096774
# Acceptance ratio gamma: 0.23516129032258065
# Acceptance ratio q_r: 0.3309677419354839
# Acceptance ratio q: 0.3203225806451613
# Acceptance ratio eta: 0.0
# Iteration: 3200
# Acceptance ratio beta: 0.2665625
# Acceptance ratio rho: 0.375625
# Acceptance ratio gamma: 0.233125
# Acceptance ratio q_r: 0.3309375
# Acceptance ratio q: 0.31625
# Acceptance ratio eta: 0.0
# Iteration: 3300
# Acceptance ratio beta: 0.26696969696969697
# Acceptance ratio rho: 0.37393939393939396
# Acceptance ratio gamma: 0.23363636363636364
# Acceptance ratio q_r: 0.3324242424242424
# Acceptance ratio q: 0.3190909090909091
# Acceptance ratio eta: 0.0
# Iteration: 3400
# Acceptance ratio beta: 0.2702941176470588
# Acceptance ratio rho: 0.3770588235294118
# Acceptance ratio gamma: 0.2338235294117647
# Acceptance ratio q_r: 0.3326470588235294
# Acceptance ratio q: 0.3197058823529412
# Acceptance ratio eta: 0.0
# Iteration: 3500
# Acceptance ratio beta: 0.27
# Acceptance ratio rho: 0.37857142857142856
# Acceptance ratio gamma: 0.2357142857142857
# Acceptance ratio q_r: 0.3342857142857143
# Acceptance ratio q: 0.31885714285714284
# Acceptance ratio eta: 0.0
# Iteration: 3600
# Acceptance ratio beta: 0.27
# Acceptance ratio rho: 0.3811111111111111
# Acceptance ratio gamma: 0.2363888888888889
# Acceptance ratio q_r: 0.33194444444444443
# Acceptance ratio q: 0.3161111111111111
# Acceptance ratio eta: 0.0
# Iteration: 3700
# Acceptance ratio beta: 0.2716216216216216
# Acceptance ratio rho: 0.38
# Acceptance ratio gamma: 0.23567567567567568
# Acceptance ratio q_r: 0.33216216216216216
# Acceptance ratio q: 0.31756756756756754
# Acceptance ratio eta: 0.0
# Iteration: 3800
# Acceptance ratio beta: 0.2710526315789474
# Acceptance ratio rho: 0.3792105263157895
# Acceptance ratio gamma: 0.23710526315789474
# Acceptance ratio q_r: 0.3360526315789474
# Acceptance ratio q: 0.31894736842105265
# Acceptance ratio eta: 0.0
# Iteration: 3900
# Acceptance ratio beta: 0.2735897435897436
# Acceptance ratio rho: 0.37846153846153846
# Acceptance ratio gamma: 0.23897435897435898
# Acceptance ratio q_r: 0.3371794871794872
# Acceptance ratio q: 0.31794871794871793
# Acceptance ratio eta: 0.0
# Iteration: 4000
# Acceptance ratio beta: 0.27325
# Acceptance ratio rho: 0.378
# Acceptance ratio gamma: 0.2395
# Acceptance ratio q_r: 0.33775
# Acceptance ratio q: 0.31625
# Acceptance ratio eta: 0.0
# Iteration: 4100
# Acceptance ratio beta: 0.275609756097561
# Acceptance ratio rho: 0.37682926829268293
# Acceptance ratio gamma: 0.23902439024390243
# Acceptance ratio q_r: 0.33682926829268295
# Acceptance ratio q: 0.31585365853658537
# Acceptance ratio eta: 0.0
# Iteration: 4200
# Acceptance ratio beta: 0.2714285714285714
# Acceptance ratio rho: 0.3788095238095238
# Acceptance ratio gamma: 0.2361904761904762
# Acceptance ratio q_r: 0.33404761904761904
# Acceptance ratio q: 0.31452380952380954
# Acceptance ratio eta: 0.0
# Iteration: 4300
# Acceptance ratio beta: 0.27232558139534885
# Acceptance ratio rho: 0.38
# Acceptance ratio gamma: 0.2355813953488372
# Acceptance ratio q_r: 0.33232558139534885
# Acceptance ratio q: 0.316046511627907
# Acceptance ratio eta: 0.0
# Iteration: 4400
# Acceptance ratio beta: 0.27204545454545453
# Acceptance ratio rho: 0.3809090909090909
# Acceptance ratio gamma: 0.235
# Acceptance ratio q_r: 0.3322727272727273
# Acceptance ratio q: 0.3170454545454545
# Acceptance ratio eta: 0.0
# Iteration: 4500
# Acceptance ratio beta: 0.27244444444444443
# Acceptance ratio rho: 0.38022222222222224
# Acceptance ratio gamma: 0.23644444444444446
# Acceptance ratio q_r: 0.3333333333333333
# Acceptance ratio q: 0.3204444444444444
# Acceptance ratio eta: 0.0
# Iteration: 4600
# Acceptance ratio beta: 0.2747826086956522
# Acceptance ratio rho: 0.37956521739130433
# Acceptance ratio gamma: 0.23891304347826087
# Acceptance ratio q_r: 0.33456521739130435
# Acceptance ratio q: 0.32065217391304346
# Acceptance ratio eta: 0.0
# Iteration: 4700
# Acceptance ratio beta: 0.2746808510638298
# Acceptance ratio rho: 0.3780851063829787
# Acceptance ratio gamma: 0.23872340425531915
# Acceptance ratio q_r: 0.33680851063829786
# Acceptance ratio q: 0.3204255319148936
# Acceptance ratio eta: 0.0
# Iteration: 4800
# Acceptance ratio beta: 0.27395833333333336
# Acceptance ratio rho: 0.37854166666666667
# Acceptance ratio gamma: 0.239375
# Acceptance ratio q_r: 0.33625
# Acceptance ratio q: 0.32083333333333336
# Acceptance ratio eta: 0.0
# Iteration: 4900
# Acceptance ratio beta: 0.2757142857142857
# Acceptance ratio rho: 0.3783673469387755
# Acceptance ratio gamma: 0.24
# Acceptance ratio q_r: 0.33693877551020407
# Acceptance ratio q: 0.32020408163265307
# Acceptance ratio eta: 0.0
# Iteration: 5000
# Acceptance ratio beta: 0.2774
# Acceptance ratio rho: 0.379
# Acceptance ratio gamma: 0.241
# Acceptance ratio q_r: 0.34
# Acceptance ratio q: 0.3206
# Acceptance ratio eta: 0.0
# Iteration: 5100
# Acceptance ratio beta: 0.2774509803921569
# Acceptance ratio rho: 0.3772549019607843
# Acceptance ratio gamma: 0.23980392156862745
# Acceptance ratio q_r: 0.33941176470588236
# Acceptance ratio q: 0.3196078431372549
# Acceptance ratio eta: 0.0
# Iteration: 5200
# Acceptance ratio beta: 0.27615384615384614
# Acceptance ratio rho: 0.3778846153846154
# Acceptance ratio gamma: 0.2401923076923077
# Acceptance ratio q_r: 0.3371153846153846
# Acceptance ratio q: 0.32
# Acceptance ratio eta: 0.0
# Iteration: 5300
# Acceptance ratio beta: 0.2760377358490566
# Acceptance ratio rho: 0.37754716981132075
# Acceptance ratio gamma: 0.23943396226415095
# Acceptance ratio q_r: 0.33867924528301885
# Acceptance ratio q: 0.3213207547169811
# Acceptance ratio eta: 0.0
# Iteration: 5400
# Acceptance ratio beta: 0.27555555555555555
# Acceptance ratio rho: 0.3761111111111111
# Acceptance ratio gamma: 0.2388888888888889
# Acceptance ratio q_r: 0.34
# Acceptance ratio q: 0.3227777777777778
# Acceptance ratio eta: 0.0
# Iteration: 5500
# Acceptance ratio beta: 0.2772727272727273
# Acceptance ratio rho: 0.37545454545454543
# Acceptance ratio gamma: 0.23945454545454545
# Acceptance ratio q_r: 0.3421818181818182
# Acceptance ratio q: 0.3230909090909091
# Acceptance ratio eta: 0.0
# Iteration: 5600
# Acceptance ratio beta: 0.2764285714285714
# Acceptance ratio rho: 0.3748214285714286
# Acceptance ratio gamma: 0.24017857142857144
# Acceptance ratio q_r: 0.34482142857142856
# Acceptance ratio q: 0.32339285714285715
# Acceptance ratio eta: 0.0
# Iteration: 5700
# Acceptance ratio beta: 0.2771929824561403
# Acceptance ratio rho: 0.3740350877192982
# Acceptance ratio gamma: 0.24017543859649124
# Acceptance ratio q_r: 0.3468421052631579
# Acceptance ratio q: 0.3236842105263158
# Acceptance ratio eta: 0.0
# Iteration: 5800
# Acceptance ratio beta: 0.27448275862068966
# Acceptance ratio rho: 0.3725862068965517
# Acceptance ratio gamma: 0.24086206896551723
# Acceptance ratio q_r: 0.3472413793103448
# Acceptance ratio q: 0.3217241379310345
# Acceptance ratio eta: 0.0
# Iteration: 5900
# Acceptance ratio beta: 0.2735593220338983
# Acceptance ratio rho: 0.37254237288135594
# Acceptance ratio gamma: 0.24067796610169492
# Acceptance ratio q_r: 0.34728813559322036
# Acceptance ratio q: 0.32237288135593223
# Acceptance ratio eta: 0.0
# Iteration: 6000
# Acceptance ratio beta: 0.275
# Acceptance ratio rho: 0.37216666666666665
# Acceptance ratio gamma: 0.2405
# Acceptance ratio q_r: 0.3476666666666667
# Acceptance ratio q: 0.3235
# Acceptance ratio eta: 0.0
# Iteration: 6100
# Acceptance ratio beta: 0.27491803278688526
# Acceptance ratio rho: 0.3722950819672131
# Acceptance ratio gamma: 0.24065573770491802
# Acceptance ratio q_r: 0.34885245901639345
# Acceptance ratio q: 0.3232786885245902
# Acceptance ratio eta: 0.0
# Iteration: 6200
# Acceptance ratio beta: 0.2746774193548387
# Acceptance ratio rho: 0.37129032258064515
# Acceptance ratio gamma: 0.24064516129032257
# Acceptance ratio q_r: 0.35016129032258064
# Acceptance ratio q: 0.3224193548387097
# Acceptance ratio eta: 0.0
# Iteration: 6300
# Acceptance ratio beta: 0.2722222222222222
# Acceptance ratio rho: 0.37126984126984125
# Acceptance ratio gamma: 0.24047619047619048
# Acceptance ratio q_r: 0.35095238095238096
# Acceptance ratio q: 0.32126984126984126
# Acceptance ratio eta: 0.0
# Iteration: 6400
# Acceptance ratio beta: 0.27234375
# Acceptance ratio rho: 0.37
# Acceptance ratio gamma: 0.24015625
# Acceptance ratio q_r: 0.35265625
# Acceptance ratio q: 0.32171875
# Acceptance ratio eta: 0.0
# Iteration: 6500
# Acceptance ratio beta: 0.2724615384615385
# Acceptance ratio rho: 0.3698461538461538
# Acceptance ratio gamma: 0.24184615384615385
# Acceptance ratio q_r: 0.35415384615384615
# Acceptance ratio q: 0.3203076923076923
# Acceptance ratio eta: 0.0
# Iteration: 6600
# Acceptance ratio beta: 0.2736363636363636
# Acceptance ratio rho: 0.3706060606060606
# Acceptance ratio gamma: 0.24166666666666667
# Acceptance ratio q_r: 0.3546969696969697
# Acceptance ratio q: 0.32015151515151513
# Acceptance ratio eta: 0.0
# Iteration: 6700
# Acceptance ratio beta: 0.2726865671641791
# Acceptance ratio rho: 0.3701492537313433
# Acceptance ratio gamma: 0.24104477611940298
# Acceptance ratio q_r: 0.35567164179104477
# Acceptance ratio q: 0.3188059701492537
# Acceptance ratio eta: 0.0
# Iteration: 6800
# Acceptance ratio beta: 0.2726470588235294
# Acceptance ratio rho: 0.36970588235294116
# Acceptance ratio gamma: 0.2422058823529412
# Acceptance ratio q_r: 0.35808823529411765
# Acceptance ratio q: 0.3195588235294118
# Acceptance ratio eta: 0.0
# Iteration: 6900
# Acceptance ratio beta: 0.27159420289855074
# Acceptance ratio rho: 0.3705797101449275
# Acceptance ratio gamma: 0.2427536231884058
# Acceptance ratio q_r: 0.35797101449275365
# Acceptance ratio q: 0.31956521739130433
# Acceptance ratio eta: 0.0
# Iteration: 7000
# Acceptance ratio beta: 0.27071428571428574
# Acceptance ratio rho: 0.3698571428571429
# Acceptance ratio gamma: 0.24242857142857144
# Acceptance ratio q_r: 0.3577142857142857
# Acceptance ratio q: 0.3191428571428571
# Acceptance ratio eta: 0.0
# Iteration: 7100
# Acceptance ratio beta: 0.271830985915493
# Acceptance ratio rho: 0.3680281690140845
# Acceptance ratio gamma: 0.2432394366197183
# Acceptance ratio q_r: 0.3576056338028169
# Acceptance ratio q: 0.3207042253521127
# Acceptance ratio eta: 0.0
# Iteration: 7200
# Acceptance ratio beta: 0.27291666666666664
# Acceptance ratio rho: 0.36819444444444444
# Acceptance ratio gamma: 0.24375
# Acceptance ratio q_r: 0.35944444444444446
# Acceptance ratio q: 0.3209722222222222
# Acceptance ratio eta: 0.0
# Iteration: 7300
# Acceptance ratio beta: 0.2719178082191781
# Acceptance ratio rho: 0.3667123287671233
# Acceptance ratio gamma: 0.24342465753424658
# Acceptance ratio q_r: 0.3591780821917808
# Acceptance ratio q: 0.3206849315068493
# Acceptance ratio eta: 0.0
# Iteration: 7400
# Acceptance ratio beta: 0.27175675675675676
# Acceptance ratio rho: 0.36783783783783786
# Acceptance ratio gamma: 0.2431081081081081
# Acceptance ratio q_r: 0.3587837837837838
# Acceptance ratio q: 0.3210810810810811
# Acceptance ratio eta: 0.0
# Iteration: 7500
# Acceptance ratio beta: 0.2708
# Acceptance ratio rho: 0.3682666666666667
# Acceptance ratio gamma: 0.2424
# Acceptance ratio q_r: 0.3586666666666667
# Acceptance ratio q: 0.3212
# Acceptance ratio eta: 0.0
# Iteration: 7600
# Acceptance ratio beta: 0.27157894736842103
# Acceptance ratio rho: 0.36855263157894735
# Acceptance ratio gamma: 0.2425
# Acceptance ratio q_r: 0.35947368421052633
# Acceptance ratio q: 0.3206578947368421
# Acceptance ratio eta: 0.0
# Iteration: 7700
# Acceptance ratio beta: 0.27064935064935064
# Acceptance ratio rho: 0.36766233766233763
# Acceptance ratio gamma: 0.2438961038961039
# Acceptance ratio q_r: 0.3596103896103896
# Acceptance ratio q: 0.32142857142857145
# Acceptance ratio eta: 0.0
# Iteration: 7800
# Acceptance ratio beta: 0.27153846153846156
# Acceptance ratio rho: 0.3687179487179487
# Acceptance ratio gamma: 0.24358974358974358
# Acceptance ratio q_r: 0.36012820512820515
# Acceptance ratio q: 0.3211538461538462
# Acceptance ratio eta: 0.0
# Iteration: 7900
# Acceptance ratio beta: 0.27177215189873416
# Acceptance ratio rho: 0.370253164556962
# Acceptance ratio gamma: 0.24329113924050633
# Acceptance ratio q_r: 0.3593670886075949
# Acceptance ratio q: 0.32126582278481014
# Acceptance ratio eta: 0.0
# Iteration: 8000
# Acceptance ratio beta: 0.2725
# Acceptance ratio rho: 0.369625
# Acceptance ratio gamma: 0.244
# Acceptance ratio q_r: 0.359
# Acceptance ratio q: 0.32125
# Acceptance ratio eta: 0.0
# Iteration: 8100
# Acceptance ratio beta: 0.27197530864197533
# Acceptance ratio rho: 0.37049382716049384
# Acceptance ratio gamma: 0.24419753086419754
# Acceptance ratio q_r: 0.3583950617283951
# Acceptance ratio q: 0.32185185185185183
# Acceptance ratio eta: 0.0
# Iteration: 8200
# Acceptance ratio beta: 0.27170731707317075
# Acceptance ratio rho: 0.3698780487804878
# Acceptance ratio gamma: 0.24353658536585365
# Acceptance ratio q_r: 0.3578048780487805
# Acceptance ratio q: 0.32170731707317074
# Acceptance ratio eta: 0.0
# Iteration: 8300
# Acceptance ratio beta: 0.2710843373493976
# Acceptance ratio rho: 0.36927710843373496
# Acceptance ratio gamma: 0.24349397590361446
# Acceptance ratio q_r: 0.35759036144578316
# Acceptance ratio q: 0.3203614457831325
# Acceptance ratio eta: 0.0
# Iteration: 8400
# Acceptance ratio beta: 0.2704761904761905
# Acceptance ratio rho: 0.36916666666666664
# Acceptance ratio gamma: 0.24357142857142858
# Acceptance ratio q_r: 0.3576190476190476
# Acceptance ratio q: 0.32
# Acceptance ratio eta: 0.0
# Iteration: 8500
# Acceptance ratio beta: 0.2703529411764706
# Acceptance ratio rho: 0.3691764705882353
# Acceptance ratio gamma: 0.24294117647058824
# Acceptance ratio q_r: 0.35811764705882354
# Acceptance ratio q: 0.3205882352941177
# Acceptance ratio eta: 0.0
# Iteration: 8600
# Acceptance ratio beta: 0.27
# Acceptance ratio rho: 0.3697674418604651
# Acceptance ratio gamma: 0.24174418604651163
# Acceptance ratio q_r: 0.3580232558139535
# Acceptance ratio q: 0.32069767441860464
# Acceptance ratio eta: 0.0
# Iteration: 8700
# Acceptance ratio beta: 0.2697701149425287
# Acceptance ratio rho: 0.36977011494252876
# Acceptance ratio gamma: 0.24126436781609195
# Acceptance ratio q_r: 0.3567816091954023
# Acceptance ratio q: 0.3198850574712644
# Acceptance ratio eta: 0.0
# Iteration: 8800
# Acceptance ratio beta: 0.2692045454545455
# Acceptance ratio rho: 0.3694318181818182
# Acceptance ratio gamma: 0.24159090909090908
# Acceptance ratio q_r: 0.3563636363636364
# Acceptance ratio q: 0.32079545454545455
# Acceptance ratio eta: 0.0
# Iteration: 8900
# Acceptance ratio beta: 0.26955056179775283
# Acceptance ratio rho: 0.3697752808988764
# Acceptance ratio gamma: 0.24235955056179775
# Acceptance ratio q_r: 0.35707865168539327
# Acceptance ratio q: 0.32134831460674157
# Acceptance ratio eta: 0.0
# Iteration: 9000
# Acceptance ratio beta: 0.2698888888888889
# Acceptance ratio rho: 0.37033333333333335
# Acceptance ratio gamma: 0.2427777777777778
# Acceptance ratio q_r: 0.35755555555555557
# Acceptance ratio q: 0.32166666666666666
# Acceptance ratio eta: 0.0
# Iteration: 9100
# Acceptance ratio beta: 0.26879120879120877
# Acceptance ratio rho: 0.3701098901098901
# Acceptance ratio gamma: 0.24307692307692308
# Acceptance ratio q_r: 0.35747252747252745
# Acceptance ratio q: 0.32153846153846155
# Acceptance ratio eta: 0.0
# Iteration: 9200
# Acceptance ratio beta: 0.2689130434782609
# Acceptance ratio rho: 0.37
# Acceptance ratio gamma: 0.24282608695652175
# Acceptance ratio q_r: 0.3584782608695652
# Acceptance ratio q: 0.3222826086956522
# Acceptance ratio eta: 0.0
# Iteration: 9300
# Acceptance ratio beta: 0.2686021505376344
# Acceptance ratio rho: 0.3689247311827957
# Acceptance ratio gamma: 0.24279569892473118
# Acceptance ratio q_r: 0.35935483870967744
# Acceptance ratio q: 0.3223655913978495
# Acceptance ratio eta: 0.0
# Iteration: 9400
# Acceptance ratio beta: 0.26861702127659576
# Acceptance ratio rho: 0.36872340425531913
# Acceptance ratio gamma: 0.2424468085106383
# Acceptance ratio q_r: 0.35936170212765955
# Acceptance ratio q: 0.3224468085106383
# Acceptance ratio eta: 0.0
# Iteration: 9500
# Acceptance ratio beta: 0.26863157894736844
# Acceptance ratio rho: 0.3684210526315789
# Acceptance ratio gamma: 0.24273684210526317
# Acceptance ratio q_r: 0.3606315789473684
# Acceptance ratio q: 0.32273684210526316
# Acceptance ratio eta: 0.0
# Iteration: 9600
# Acceptance ratio beta: 0.2680208333333333
# Acceptance ratio rho: 0.36770833333333336
# Acceptance ratio gamma: 0.24302083333333332
# Acceptance ratio q_r: 0.3609375
# Acceptance ratio q: 0.3227083333333333
# Acceptance ratio eta: 0.0
# Iteration: 9700
# Acceptance ratio beta: 0.26793814432989693
# Acceptance ratio rho: 0.3677319587628866
# Acceptance ratio gamma: 0.2422680412371134
# Acceptance ratio q_r: 0.36030927835051546
# Acceptance ratio q: 0.3224742268041237
# Acceptance ratio eta: 0.0
# Iteration: 9800
# Acceptance ratio beta: 0.26846938775510204
# Acceptance ratio rho: 0.3680612244897959
# Acceptance ratio gamma: 0.2416326530612245
# Acceptance ratio q_r: 0.36
# Acceptance ratio q: 0.3216326530612245
# Acceptance ratio eta: 0.0
# Iteration: 9900
# Acceptance ratio beta: 0.268989898989899
# Acceptance ratio rho: 0.36808080808080806
# Acceptance ratio gamma: 0.24151515151515152
# Acceptance ratio q_r: 0.3603030303030303
# Acceptance ratio q: 0.32303030303030306
# Acceptance ratio eta: 0.0

# %% [markdown]
# ### Traceplots, histograms and estimates

# %%
Gibbs_data = {}

k=0
    
Gibbs_data[str(k)] = {}

beta_MCMC  = beta_chain 
q_r_MCMC   = q_r_chain  
rho_MCMC   = rho_chain  
gamma_MCMC = gamma_chain
q_MCMC     = q_chain    

Gibbs_data[str(k)]["beta"] = beta_MCMC
Gibbs_data[str(k)]["rho"]  = rho_MCMC
Gibbs_data[str(k)]["gamma"]= gamma_MCMC
Gibbs_data[str(k)]["q_r"]  = q_r_MCMC
Gibbs_data[str(k)]["q"]  = q_MCMC

# %%
colors = ["purple", "pink", "orange", "darkgrey", "brown", "darkgreen"] 
labels = [r"$\beta$    ", r"$\lambda$    ", r"$\rho$    ", r"$\gamma$    ", r"$q^{2,3}$        ", r"$q^{3,4}$        "]
keys = ["beta", "q_r", "rho", "gamma", "q"]


fig, ax = plt.subplots(6,2, figsize = (10, 10), dpi =100)

for i in range(0,6): # use 6 for the eta
        
    for j in range(0, 1):
        if j==0:
            ax[i,j].set_ylabel(labels[i], fontsize=16, rotation =0)
            

        if i<4:
            ax[i,j].plot(Gibbs_data[str(j)][keys[i]], color = colors[i], linewidth=0.25)
            ax[i,2*j+1].hist(Gibbs_data[str(j)][keys[i]], color = colors[i], orientation="horizontal", bins = 20, density =True)
            ax[i,j].xaxis.set_tick_params(labelsize=10)
            ax[i,j].yaxis.set_tick_params(labelsize=10)
        else:
            ax[i,j].plot(Gibbs_data[str(j)][keys[4]][i-3,i-3+1,:], color = colors[i], linewidth=0.25)
            ax[i,2*j+1].hist(Gibbs_data[str(j)][keys[4]][i-3,i-3+1,:], color = colors[i], orientation="horizontal", bins = 20, density =True)
            ax[i,j].xaxis.set_tick_params(labelsize=10)
            ax[i,j].yaxis.set_tick_params(labelsize=10)

# %%
spaces = ["       ", " ", " ", "         ","   ","   ",]
    
print("MCMC using metropolis within gibbs")
for j in range(0, 1): # use 6 for eta
    string = ""
    for i in range(0, 4):
        string = string + keys[i]+" "+ str(np.round(np.mean(Gibbs_data[str(j)][keys[i]]), 3))+" "+ "("+ str(np.round(np.std(Gibbs_data[str(j)][keys[i]]),4))+ "); "
    
    string = string + keys[4]+"_12 "+ str(np.round(np.mean(Gibbs_data[str(j)][keys[4]][1,2,:]), 3))+ "("+ str(np.round(np.std(Gibbs_data[str(j)][keys[4]][1,2,:]),4))+ "); "
    string = string + keys[4]+"_23 "+ str(np.round(np.mean(Gibbs_data[str(j)][keys[4]][2,3,:]), 3))+ "("+ str(np.round(np.std(Gibbs_data[str(j)][keys[4]][2,3,:]),4))+ "); "
    
    r_0 = Gibbs_data[str(j)]["beta"]/Gibbs_data[str(j)]["gamma"]
    string = string + "R_0 "+ str(np.round(np.mean(r_0),3)) +"("+str(np.round(np.std(r_0),4))+")" 
    print(string)
# Out:
# MCMC using metropolis within gibbs
# beta 0.21 (0.0165); q_r 0.216 (0.0611); rho 0.205 (0.0358); gamma 0.15 (0.0146); q_12 0.68(0.1579); q_23 0.572(0.1364); R_0 1.402(0.077)

# %% [markdown]
# ## EM algorithm on sythetic data from the Ebola model

# %% [markdown]
# We show how to use the EM algortihm. The data are the same of the MCMC.

# %% [markdown]
# ### Set the parameters

# %%
beta_prior = np.array([0,0])
#setting the second argument to 0 gives a flat prior, first argument does nothing
rho_prior = np.array([0,0])
gamma_prior = np.array([0,0])

n_grid = 5
beta_grid = np.linspace(0.01,0.4,n_grid)
q_r_grid = np.linspace(0.01,0.4,n_grid)

rho_out = np.zeros([n_grid,n_grid])
gamma_out = np.zeros([n_grid,n_grid])
q_out = np.zeros([4,4,n_grid,n_grid])
init_pop_out = np.zeros([4,n_grid, n_grid])
log_like_out = np.zeros([n_grid,n_grid])

# %% [markdown]
# ### Run the EM
#
# We envaluate $\beta$ and $\lambda$ on a grid and we learn the other parameters from the EM algorithm.

# %%
n_iter = 100

for i in range(n_grid):
    #EM = EM_approxSEIR(N, beta_grid[i], 2, 1, q.copy(), init_pop.copy(), y, 0)
    for j in range(n_grid):
        print('i =', i, 'j =',j)
        EM = EMSEIR.EM_approxSEIR_expanded(N, beta_grid[i], rho_0, gamma_0,  q_0, eta_zero_0, q_r_grid[j], t_star, y, 0, 
                               beta_prior, rho_prior, gamma_prior)
    
        beta_est, rho_est, gamma_est, q_est, init_pop_est, log_like_out[i,j] = EM.iterate(n_iter)
    
        rho_out[i,j] = rho_est[-1]
        gamma_out[i,j] = gamma_est[-1]
        q_out[:,:,i,j] = q_est[:,:,-1]
        init_pop_out[:,i,j] = init_pop_est[:,-1]
# Out:
# i = 0 j = 0
# i = 0 j = 1
# i = 0 j = 2
# i = 0 j = 3
# i = 0 j = 4
# i = 1 j = 0
# i = 1 j = 1
# i = 1 j = 2
# i = 1 j = 3
# i = 1 j = 4
# i = 2 j = 0
# i = 2 j = 1
# i = 2 j = 2
# i = 2 j = 3
# i = 2 j = 4
# i = 3 j = 0
# i = 3 j = 1
# i = 3 j = 2
# i = 3 j = 3
# i = 3 j = 4
# i = 4 j = 0
# i = 4 j = 1
# i = 4 j = 2
# i = 4 j = 3
# i = 4 j = 4

# %% [markdown]
# We report the combination with the highest likelihood

# %%
i_max = np.unravel_index(np.argmax(log_like_out, axis=None), log_like_out.shape)

print('index of best fitting beta, q_r = ', i_max)

print('beta_grid =', beta_grid)
print('q_r_grid =',  q_r_grid)


print('beta =',beta_grid[i_max[0]])
print('rho =',rho_out[i_max[0], i_max[1]])
print('gamma =',gamma_out[i_max[0], i_max[1]])
print('q_r =',q_r_grid[i_max[1]])
# Out:
# index of best fitting beta, q_r =  (2, 1)
# beta_grid = [0.01   0.1075 0.205  0.3025 0.4   ]
# q_r_grid = [0.01   0.1075 0.205  0.3025 0.4   ]
# beta = 0.20500000000000002
# rho = 0.4237041303318309
# gamma = 0.16203804401325805
# q_r = 0.1075

# %% [markdown]
# ## MCMC on the 1995 Ebola outbreak data

# %% [markdown]
# ### Set the parameters

# %% [markdown]
# Load the data and set the main parameters

# %%
data = pd.read_csv("EBOLA.csv", sep =";")
ebola_I = data["onset"].values
ebola_R = data["death"].values

# Start the count from 1st March
first_march = 54

T_end = np.size(ebola_I)

y = np.zeros((4,4, np.size(ebola_I)-first_march+1))

y[1, 2, :] = ebola_I[first_march-1:]
y[2, 3, :] = ebola_R[first_march-1:]

# epidemic time in number of days counting from 1st March
T = np.size(ebola_I)-first_march+1 

# population size
N     = 5364501
# control measurements in days counting from 1st March
t_star = 70
# initial population as in Lekone
eta_zero = np.array([5364500/5364501, 1/5364501, 0, 0]) #paper uses an even smaller I_0 than this

# %% [markdown]
# Plot the data

# %%
# separate
# two separate pictures
import matplotlib.gridspec as gridspec


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5), dpi=200)
fig.subplots_adjust(wspace=0.1, hspace=0)

ax1.set_xlabel('Days from March 1, 1995', fontsize=16)
ax1.set_ylabel('Daily reported new cases', fontsize=16)

ax2.set_xlabel('Day of death from March 1, 1995', fontsize=16)
ax2.set_ylabel('Daily reported deaths', fontsize=16)

ax1.xaxis.set_tick_params(labelsize=10)
ax1.yaxis.set_tick_params(labelsize=10)

ax2.xaxis.set_tick_params(labelsize=10)
ax2.yaxis.set_tick_params(labelsize=10)

ax1.set_xlim((0, 150))
ax2.set_xlim((0, 150))

ax1.bar(np.linspace(1, len(ebola_I[53:]), len(ebola_I[first_march:])), ebola_I[first_march:], color = "red", label = r"Infectious", width = 0.75)
ax2.bar(np.linspace(1, len(ebola_R[53:]), len(ebola_R[first_march:])), ebola_R[first_march:], color = "orange", label = r"Removed", width = 0.75)

ax1.axvline(t_star, color = "blue", label = "Control measures", linewidth =2)
ax2.axvline(t_star, color = "blue", label = "Control measures", linewidth =2)

# ax1.legend(loc='upper right', fontsize=12)
# ax2.legend(loc='upper right', fontsize=12)

# %% [markdown]
# Set the remaining parameters

# %%
# Set the initial conditions
np.random.seed(seed)
beta_0  = 0.37     
rho_0   = 0.092   
gamma_0 = 0.16

q_0 = np.zeros((4,4))
q_0[1,2] = 291/316 #accounting for under-reporting as in the paper
q_0[2,3] = 236/316 #

q_r_0 = 0.368  

eta_zero_0 = np.array([5364500/5364501, 1/5364501, 0,0]) #paper uses an even smaller I_0 than this
x_0 = np.array([1, 1, 1, 1])

# Set the priors
beta_prior = np.array([ 2, 10])
rho_prior = np.array([  2, 10])
gamma_prior = np.array([2, 14])
q_r_prior = np.array([ 2, 10])

q_prior= np.array([1, 1])

eta_zero_prior = np.array([1, 1, 1, 1])


#Set the proposal
beta_proposal_variance = 0.03
rho_proposal_variance = 0.02
gamma_proposal_variance = 0.02
q_r_proposal_variance = 0.2

q_proposal_variance = 0.07

# %% [markdown]
# ### Run the MCMC

# %% [markdown]
# It took around 10min on a 4 cores Intel(R) Core(TM) i7-7700HQ CPU @2.80GHz).Remark that $10^5$ iterations is not enough to get stationarity, we recommend using at least $10^6$.

# %%
# MCMC
MCMC_EBOLA = MCMCSEIR_expanded.MCMC_SEIR_expanded(N, t_star, beta_prior, rho_prior, gamma_prior, q_prior, q_r_prior, eta_zero_prior, beta_proposal_variance, rho_proposal_variance, gamma_proposal_variance, q_proposal_variance, q_r_proposal_variance)

np.random.seed(seed)

sample_size = 10000
beta_chain, rho_chain, gamma_chain, eta_zero_chain, q_chain, x_chain, q_r_chain = MCMC_EBOLA.posterior_sample( sample_size, y, beta_0, rho_0, gamma_0, eta_zero_0, x_0, q_0, q_r_0)
# Out:
# Iteration: 100
# Acceptance ratio beta: 0.41
# Acceptance ratio rho: 0.35
# Acceptance ratio gamma: 0.4
# Acceptance ratio q_r: 0.32
# Acceptance ratio q: 0.43
# Acceptance ratio eta: 0.0
# Iteration: 200
# Acceptance ratio beta: 0.41
# Acceptance ratio rho: 0.325
# Acceptance ratio gamma: 0.37
# Acceptance ratio q_r: 0.375
# Acceptance ratio q: 0.365
# Acceptance ratio eta: 0.0
# Iteration: 300
# Acceptance ratio beta: 0.38666666666666666
# Acceptance ratio rho: 0.32666666666666666
# Acceptance ratio gamma: 0.33666666666666667
# Acceptance ratio q_r: 0.30333333333333334
# Acceptance ratio q: 0.3233333333333333
# Acceptance ratio eta: 0.0
# Iteration: 400
# Acceptance ratio beta: 0.38
# Acceptance ratio rho: 0.3125
# Acceptance ratio gamma: 0.3075
# Acceptance ratio q_r: 0.3
# Acceptance ratio q: 0.2925
# Acceptance ratio eta: 0.0
# Iteration: 500
# Acceptance ratio beta: 0.38
# Acceptance ratio rho: 0.304
# Acceptance ratio gamma: 0.336
# Acceptance ratio q_r: 0.31
# Acceptance ratio q: 0.288
# Acceptance ratio eta: 0.0
# Iteration: 600
# Acceptance ratio beta: 0.37333333333333335
# Acceptance ratio rho: 0.3
# Acceptance ratio gamma: 0.34833333333333333
# Acceptance ratio q_r: 0.30666666666666664
# Acceptance ratio q: 0.2816666666666667
# Acceptance ratio eta: 0.0
# Iteration: 700
# Acceptance ratio beta: 0.3628571428571429
# Acceptance ratio rho: 0.32142857142857145
# Acceptance ratio gamma: 0.3342857142857143
# Acceptance ratio q_r: 0.28714285714285714
# Acceptance ratio q: 0.2857142857142857
# Acceptance ratio eta: 0.0
# Iteration: 800
# Acceptance ratio beta: 0.35375
# Acceptance ratio rho: 0.35625
# Acceptance ratio gamma: 0.34375
# Acceptance ratio q_r: 0.2625
# Acceptance ratio q: 0.2925
# Acceptance ratio eta: 0.0
# Iteration: 900
# Acceptance ratio beta: 0.35444444444444445
# Acceptance ratio rho: 0.3611111111111111
# Acceptance ratio gamma: 0.3377777777777778
# Acceptance ratio q_r: 0.27555555555555555
# Acceptance ratio q: 0.29
# Acceptance ratio eta: 0.0
# Iteration: 1000
# Acceptance ratio beta: 0.357
# Acceptance ratio rho: 0.354
# Acceptance ratio gamma: 0.335
# Acceptance ratio q_r: 0.283
# Acceptance ratio q: 0.287
# Acceptance ratio eta: 0.0
# Iteration: 1100
# Acceptance ratio beta: 0.35363636363636364
# Acceptance ratio rho: 0.35
# Acceptance ratio gamma: 0.3472727272727273
# Acceptance ratio q_r: 0.2918181818181818
# Acceptance ratio q: 0.28545454545454546
# Acceptance ratio eta: 0.0
# Iteration: 1200
# Acceptance ratio beta: 0.3525
# Acceptance ratio rho: 0.3525
# Acceptance ratio gamma: 0.3466666666666667
# Acceptance ratio q_r: 0.2925
# Acceptance ratio q: 0.2833333333333333
# Acceptance ratio eta: 0.0
# Iteration: 1300
# Acceptance ratio beta: 0.3546153846153846
# Acceptance ratio rho: 0.3546153846153846
# Acceptance ratio gamma: 0.3453846153846154
# Acceptance ratio q_r: 0.30153846153846153
# Acceptance ratio q: 0.2907692307692308
# Acceptance ratio eta: 0.0
# Iteration: 1400
# Acceptance ratio beta: 0.35428571428571426
# Acceptance ratio rho: 0.3485714285714286
# Acceptance ratio gamma: 0.34
# Acceptance ratio q_r: 0.30428571428571427
# Acceptance ratio q: 0.2914285714285714
# Acceptance ratio eta: 0.0
# Iteration: 1500
# Acceptance ratio beta: 0.356
# Acceptance ratio rho: 0.344
# Acceptance ratio gamma: 0.342
# Acceptance ratio q_r: 0.30666666666666664
# Acceptance ratio q: 0.286
# Acceptance ratio eta: 0.0
# Iteration: 1600
# Acceptance ratio beta: 0.35875
# Acceptance ratio rho: 0.344375
# Acceptance ratio gamma: 0.34125
# Acceptance ratio q_r: 0.306875
# Acceptance ratio q: 0.28375
# Acceptance ratio eta: 0.0
# Iteration: 1700
# Acceptance ratio beta: 0.3611764705882353
# Acceptance ratio rho: 0.3382352941176471
# Acceptance ratio gamma: 0.3382352941176471
# Acceptance ratio q_r: 0.31529411764705884
# Acceptance ratio q: 0.28352941176470586
# Acceptance ratio eta: 0.0
# Iteration: 1800
# Acceptance ratio beta: 0.36277777777777775
# Acceptance ratio rho: 0.335
# Acceptance ratio gamma: 0.34055555555555556
# Acceptance ratio q_r: 0.3188888888888889
# Acceptance ratio q: 0.2838888888888889
# Acceptance ratio eta: 0.0
# Iteration: 1900
# Acceptance ratio beta: 0.36526315789473685
# Acceptance ratio rho: 0.3368421052631579
# Acceptance ratio gamma: 0.3452631578947368
# Acceptance ratio q_r: 0.3215789473684211
# Acceptance ratio q: 0.28421052631578947
# Acceptance ratio eta: 0.0
# Iteration: 2000
# Acceptance ratio beta: 0.3635
# Acceptance ratio rho: 0.3375
# Acceptance ratio gamma: 0.3455
# Acceptance ratio q_r: 0.317
# Acceptance ratio q: 0.2815
# Acceptance ratio eta: 0.0
# Iteration: 2100
# Acceptance ratio beta: 0.36333333333333334
# Acceptance ratio rho: 0.3323809523809524
# Acceptance ratio gamma: 0.34285714285714286
# Acceptance ratio q_r: 0.3180952380952381
# Acceptance ratio q: 0.27666666666666667
# Acceptance ratio eta: 0.0
# Iteration: 2200
# Acceptance ratio beta: 0.36
# Acceptance ratio rho: 0.3290909090909091
# Acceptance ratio gamma: 0.3418181818181818
# Acceptance ratio q_r: 0.31681818181818183
# Acceptance ratio q: 0.26954545454545453
# Acceptance ratio eta: 0.0
# Iteration: 2300
# Acceptance ratio beta: 0.3630434782608696
# Acceptance ratio rho: 0.3269565217391304
# Acceptance ratio gamma: 0.34391304347826085
# Acceptance ratio q_r: 0.32217391304347825
# Acceptance ratio q: 0.27
# Acceptance ratio eta: 0.0
# Iteration: 2400
# Acceptance ratio beta: 0.36125
# Acceptance ratio rho: 0.3254166666666667
# Acceptance ratio gamma: 0.34291666666666665
# Acceptance ratio q_r: 0.32458333333333333
# Acceptance ratio q: 0.27166666666666667
# Acceptance ratio eta: 0.0
# Iteration: 2500
# Acceptance ratio beta: 0.3624
# Acceptance ratio rho: 0.324
# Acceptance ratio gamma: 0.3452
# Acceptance ratio q_r: 0.3264
# Acceptance ratio q: 0.2744
# Acceptance ratio eta: 0.0
# Iteration: 2600
# Acceptance ratio beta: 0.3596153846153846
# Acceptance ratio rho: 0.3203846153846154
# Acceptance ratio gamma: 0.3446153846153846
# Acceptance ratio q_r: 0.3292307692307692
# Acceptance ratio q: 0.27
# Acceptance ratio eta: 0.0
# Iteration: 2700
# Acceptance ratio beta: 0.36074074074074075
# Acceptance ratio rho: 0.31703703703703706
# Acceptance ratio gamma: 0.34629629629629627
# Acceptance ratio q_r: 0.33296296296296296
# Acceptance ratio q: 0.27037037037037037
# Acceptance ratio eta: 0.0
# Iteration: 2800
# Acceptance ratio beta: 0.35928571428571426
# Acceptance ratio rho: 0.3192857142857143
# Acceptance ratio gamma: 0.34714285714285714
# Acceptance ratio q_r: 0.32821428571428574
# Acceptance ratio q: 0.27285714285714285
# Acceptance ratio eta: 0.0
# Iteration: 2900
# Acceptance ratio beta: 0.35758620689655174
# Acceptance ratio rho: 0.3196551724137931
# Acceptance ratio gamma: 0.3489655172413793
# Acceptance ratio q_r: 0.32413793103448274
# Acceptance ratio q: 0.27206896551724136
# Acceptance ratio eta: 0.0
# Iteration: 3000
# Acceptance ratio beta: 0.358
# Acceptance ratio rho: 0.321
# Acceptance ratio gamma: 0.3496666666666667
# Acceptance ratio q_r: 0.32566666666666666
# Acceptance ratio q: 0.274
# Acceptance ratio eta: 0.0
# Iteration: 3100
# Acceptance ratio beta: 0.35838709677419356
# Acceptance ratio rho: 0.32
# Acceptance ratio gamma: 0.3487096774193548
# Acceptance ratio q_r: 0.33064516129032256
# Acceptance ratio q: 0.2725806451612903
# Acceptance ratio eta: 0.0
# Iteration: 3200
# Acceptance ratio beta: 0.3596875
# Acceptance ratio rho: 0.3184375
# Acceptance ratio gamma: 0.35
# Acceptance ratio q_r: 0.33375
# Acceptance ratio q: 0.268125
# Acceptance ratio eta: 0.0
# Iteration: 3300
# Acceptance ratio beta: 0.3612121212121212
# Acceptance ratio rho: 0.3184848484848485
# Acceptance ratio gamma: 0.3512121212121212
# Acceptance ratio q_r: 0.33424242424242423
# Acceptance ratio q: 0.2690909090909091
# Acceptance ratio eta: 0.0
# Iteration: 3400
# Acceptance ratio beta: 0.3623529411764706
# Acceptance ratio rho: 0.3164705882352941
# Acceptance ratio gamma: 0.3517647058823529
# Acceptance ratio q_r: 0.3397058823529412
# Acceptance ratio q: 0.2691176470588235
# Acceptance ratio eta: 0.0
# Iteration: 3500
# Acceptance ratio beta: 0.3628571428571429
# Acceptance ratio rho: 0.318
# Acceptance ratio gamma: 0.3502857142857143
# Acceptance ratio q_r: 0.33685714285714285
# Acceptance ratio q: 0.268
# Acceptance ratio eta: 0.0
# Iteration: 3600
# Acceptance ratio beta: 0.3647222222222222
# Acceptance ratio rho: 0.31722222222222224
# Acceptance ratio gamma: 0.3486111111111111
# Acceptance ratio q_r: 0.3422222222222222
# Acceptance ratio q: 0.2683333333333333
# Acceptance ratio eta: 0.0
# Iteration: 3700
# Acceptance ratio beta: 0.3662162162162162
# Acceptance ratio rho: 0.3172972972972973
# Acceptance ratio gamma: 0.3497297297297297
# Acceptance ratio q_r: 0.34405405405405404
# Acceptance ratio q: 0.27
# Acceptance ratio eta: 0.0
# Iteration: 3800
# Acceptance ratio beta: 0.3676315789473684
# Acceptance ratio rho: 0.32105263157894737
# Acceptance ratio gamma: 0.3513157894736842
# Acceptance ratio q_r: 0.34657894736842104
# Acceptance ratio q: 0.27052631578947367
# Acceptance ratio eta: 0.0
# Iteration: 3900
# Acceptance ratio beta: 0.36666666666666664
# Acceptance ratio rho: 0.31974358974358974
# Acceptance ratio gamma: 0.3517948717948718
# Acceptance ratio q_r: 0.34512820512820513
# Acceptance ratio q: 0.27205128205128204
# Acceptance ratio eta: 0.0
# Iteration: 4000
# Acceptance ratio beta: 0.3685
# Acceptance ratio rho: 0.32175
# Acceptance ratio gamma: 0.3525
# Acceptance ratio q_r: 0.3405
# Acceptance ratio q: 0.2745
# Acceptance ratio eta: 0.0
# Iteration: 4100
# Acceptance ratio beta: 0.36804878048780487
# Acceptance ratio rho: 0.32390243902439025
# Acceptance ratio gamma: 0.35292682926829266
# Acceptance ratio q_r: 0.33902439024390246
# Acceptance ratio q: 0.27658536585365856
# Acceptance ratio eta: 0.0
# Iteration: 4200
# Acceptance ratio beta: 0.36714285714285716
# Acceptance ratio rho: 0.3238095238095238
# Acceptance ratio gamma: 0.3514285714285714
# Acceptance ratio q_r: 0.3357142857142857
# Acceptance ratio q: 0.2754761904761905
# Acceptance ratio eta: 0.0
# Iteration: 4300
# Acceptance ratio beta: 0.36697674418604653
# Acceptance ratio rho: 0.326046511627907
# Acceptance ratio gamma: 0.35232558139534886
# Acceptance ratio q_r: 0.3353488372093023
# Acceptance ratio q: 0.2786046511627907
# Acceptance ratio eta: 0.0
# Iteration: 4400
# Acceptance ratio beta: 0.36727272727272725
# Acceptance ratio rho: 0.32522727272727275
# Acceptance ratio gamma: 0.35568181818181815
# Acceptance ratio q_r: 0.3386363636363636
# Acceptance ratio q: 0.2790909090909091
# Acceptance ratio eta: 0.0
# Iteration: 4500
# Acceptance ratio beta: 0.3662222222222222
# Acceptance ratio rho: 0.3248888888888889
# Acceptance ratio gamma: 0.35844444444444445
# Acceptance ratio q_r: 0.3353333333333333
# Acceptance ratio q: 0.27644444444444444
# Acceptance ratio eta: 0.0
# Iteration: 4600
# Acceptance ratio beta: 0.36543478260869566
# Acceptance ratio rho: 0.3241304347826087
# Acceptance ratio gamma: 0.3576086956521739
# Acceptance ratio q_r: 0.33608695652173914
# Acceptance ratio q: 0.27652173913043476
# Acceptance ratio eta: 0.0
# Iteration: 4700
# Acceptance ratio beta: 0.3659574468085106
# Acceptance ratio rho: 0.32574468085106384
# Acceptance ratio gamma: 0.3570212765957447
# Acceptance ratio q_r: 0.33489361702127657
# Acceptance ratio q: 0.27787234042553194
# Acceptance ratio eta: 0.0
# Iteration: 4800
# Acceptance ratio beta: 0.36645833333333333
# Acceptance ratio rho: 0.32625
# Acceptance ratio gamma: 0.35875
# Acceptance ratio q_r: 0.33541666666666664
# Acceptance ratio q: 0.28020833333333334
# Acceptance ratio eta: 0.0
# Iteration: 4900
# Acceptance ratio beta: 0.36673469387755103
# Acceptance ratio rho: 0.3248979591836735
# Acceptance ratio gamma: 0.3593877551020408
# Acceptance ratio q_r: 0.3353061224489796
# Acceptance ratio q: 0.27877551020408164
# Acceptance ratio eta: 0.0
# Iteration: 5000
# Acceptance ratio beta: 0.3668
# Acceptance ratio rho: 0.3264
# Acceptance ratio gamma: 0.3608
# Acceptance ratio q_r: 0.3378
# Acceptance ratio q: 0.2784
# Acceptance ratio eta: 0.0
# Iteration: 5100
# Acceptance ratio beta: 0.36686274509803923
# Acceptance ratio rho: 0.3264705882352941
# Acceptance ratio gamma: 0.36098039215686273
# Acceptance ratio q_r: 0.3423529411764706
# Acceptance ratio q: 0.27725490196078434
# Acceptance ratio eta: 0.0
# Iteration: 5200
# Acceptance ratio beta: 0.36615384615384616
# Acceptance ratio rho: 0.3267307692307692
# Acceptance ratio gamma: 0.3605769230769231
# Acceptance ratio q_r: 0.34192307692307694
# Acceptance ratio q: 0.27692307692307694
# Acceptance ratio eta: 0.0
# Iteration: 5300
# Acceptance ratio beta: 0.36660377358490565
# Acceptance ratio rho: 0.32622641509433964
# Acceptance ratio gamma: 0.3618867924528302
# Acceptance ratio q_r: 0.339811320754717
# Acceptance ratio q: 0.28
# Acceptance ratio eta: 0.0
# Iteration: 5400
# Acceptance ratio beta: 0.36648148148148146
# Acceptance ratio rho: 0.32481481481481483
# Acceptance ratio gamma: 0.36314814814814816
# Acceptance ratio q_r: 0.3416666666666667
# Acceptance ratio q: 0.2824074074074074
# Acceptance ratio eta: 0.0
# Iteration: 5500
# Acceptance ratio beta: 0.3643636363636364
# Acceptance ratio rho: 0.3249090909090909
# Acceptance ratio gamma: 0.3623636363636364
# Acceptance ratio q_r: 0.34
# Acceptance ratio q: 0.2829090909090909
# Acceptance ratio eta: 0.0
# Iteration: 5600
# Acceptance ratio beta: 0.3628571428571429
# Acceptance ratio rho: 0.3244642857142857
# Acceptance ratio gamma: 0.3607142857142857
# Acceptance ratio q_r: 0.3385714285714286
# Acceptance ratio q: 0.27982142857142855
# Acceptance ratio eta: 0.0
# Iteration: 5700
# Acceptance ratio beta: 0.3631578947368421
# Acceptance ratio rho: 0.3280701754385965
# Acceptance ratio gamma: 0.36105263157894735
# Acceptance ratio q_r: 0.3354385964912281
# Acceptance ratio q: 0.28157894736842104
# Acceptance ratio eta: 0.0
# Iteration: 5800
# Acceptance ratio beta: 0.3612068965517241
# Acceptance ratio rho: 0.32620689655172413
# Acceptance ratio gamma: 0.3618965517241379
# Acceptance ratio q_r: 0.3360344827586207
# Acceptance ratio q: 0.2810344827586207
# Acceptance ratio eta: 0.0
# Iteration: 5900
# Acceptance ratio beta: 0.3610169491525424
# Acceptance ratio rho: 0.32593220338983053
# Acceptance ratio gamma: 0.3628813559322034
# Acceptance ratio q_r: 0.3359322033898305
# Acceptance ratio q: 0.28084745762711866
# Acceptance ratio eta: 0.0
# Iteration: 6000
# Acceptance ratio beta: 0.3625
# Acceptance ratio rho: 0.32466666666666666
# Acceptance ratio gamma: 0.3636666666666667
# Acceptance ratio q_r: 0.3365
# Acceptance ratio q: 0.2801666666666667
# Acceptance ratio eta: 0.0
# Iteration: 6100
# Acceptance ratio beta: 0.3619672131147541
# Acceptance ratio rho: 0.32278688524590166
# Acceptance ratio gamma: 0.36475409836065575
# Acceptance ratio q_r: 0.33377049180327867
# Acceptance ratio q: 0.2772131147540984
# Acceptance ratio eta: 0.0
# Iteration: 6200
# Acceptance ratio beta: 0.36161290322580647
# Acceptance ratio rho: 0.3211290322580645
# Acceptance ratio gamma: 0.3658064516129032
# Acceptance ratio q_r: 0.3317741935483871
# Acceptance ratio q: 0.2762903225806452
# Acceptance ratio eta: 0.0
# Iteration: 6300
# Acceptance ratio beta: 0.36158730158730157
# Acceptance ratio rho: 0.3198412698412698
# Acceptance ratio gamma: 0.36634920634920637
# Acceptance ratio q_r: 0.3315873015873016
# Acceptance ratio q: 0.2749206349206349
# Acceptance ratio eta: 0.0
# Iteration: 6400
# Acceptance ratio beta: 0.3625
# Acceptance ratio rho: 0.319375
# Acceptance ratio gamma: 0.36640625
# Acceptance ratio q_r: 0.33265625
# Acceptance ratio q: 0.2734375
# Acceptance ratio eta: 0.0
# Iteration: 6500
# Acceptance ratio beta: 0.3627692307692308
# Acceptance ratio rho: 0.31876923076923075
# Acceptance ratio gamma: 0.36723076923076925
# Acceptance ratio q_r: 0.3353846153846154
# Acceptance ratio q: 0.2726153846153846
# Acceptance ratio eta: 0.0
# Iteration: 6600
# Acceptance ratio beta: 0.36378787878787877
# Acceptance ratio rho: 0.31893939393939397
# Acceptance ratio gamma: 0.36833333333333335
# Acceptance ratio q_r: 0.33606060606060606
# Acceptance ratio q: 0.2731818181818182
# Acceptance ratio eta: 0.0
# Iteration: 6700
# Acceptance ratio beta: 0.3637313432835821
# Acceptance ratio rho: 0.3192537313432836
# Acceptance ratio gamma: 0.36850746268656714
# Acceptance ratio q_r: 0.3382089552238806
# Acceptance ratio q: 0.2738805970149254
# Acceptance ratio eta: 0.0
# Iteration: 6800
# Acceptance ratio beta: 0.3635294117647059
# Acceptance ratio rho: 0.31985294117647056
# Acceptance ratio gamma: 0.36867647058823527
# Acceptance ratio q_r: 0.3391176470588235
# Acceptance ratio q: 0.27308823529411763
# Acceptance ratio eta: 0.0
# Iteration: 6900
# Acceptance ratio beta: 0.36289855072463767
# Acceptance ratio rho: 0.3210144927536232
# Acceptance ratio gamma: 0.3671014492753623
# Acceptance ratio q_r: 0.3382608695652174
# Acceptance ratio q: 0.27318840579710146
# Acceptance ratio eta: 0.0
# Iteration: 7000
# Acceptance ratio beta: 0.3638571428571429
# Acceptance ratio rho: 0.3221428571428571
# Acceptance ratio gamma: 0.3678571428571429
# Acceptance ratio q_r: 0.33914285714285713
# Acceptance ratio q: 0.2747142857142857
# Acceptance ratio eta: 0.0
# Iteration: 7100
# Acceptance ratio beta: 0.36422535211267604
# Acceptance ratio rho: 0.32140845070422536
# Acceptance ratio gamma: 0.3680281690140845
# Acceptance ratio q_r: 0.34225352112676055
# Acceptance ratio q: 0.27507042253521125
# Acceptance ratio eta: 0.0
# Iteration: 7200
# Acceptance ratio beta: 0.3630555555555556
# Acceptance ratio rho: 0.32125
# Acceptance ratio gamma: 0.36736111111111114
# Acceptance ratio q_r: 0.34
# Acceptance ratio q: 0.2743055555555556
# Acceptance ratio eta: 0.0
# Iteration: 7300
# Acceptance ratio beta: 0.3628767123287671
# Acceptance ratio rho: 0.3198630136986301
# Acceptance ratio gamma: 0.3680821917808219
# Acceptance ratio q_r: 0.34054794520547943
# Acceptance ratio q: 0.27493150684931505
# Acceptance ratio eta: 0.0
# Iteration: 7400
# Acceptance ratio beta: 0.3622972972972973
# Acceptance ratio rho: 0.32
# Acceptance ratio gamma: 0.3677027027027027
# Acceptance ratio q_r: 0.34175675675675676
# Acceptance ratio q: 0.2762162162162162
# Acceptance ratio eta: 0.0
# Iteration: 7500
# Acceptance ratio beta: 0.3628
# Acceptance ratio rho: 0.3197333333333333
# Acceptance ratio gamma: 0.3678666666666667
# Acceptance ratio q_r: 0.34186666666666665
# Acceptance ratio q: 0.2769333333333333
# Acceptance ratio eta: 0.0
# Iteration: 7600
# Acceptance ratio beta: 0.36289473684210527
# Acceptance ratio rho: 0.31934210526315787
# Acceptance ratio gamma: 0.3668421052631579
# Acceptance ratio q_r: 0.3427631578947368
# Acceptance ratio q: 0.2760526315789474
# Acceptance ratio eta: 0.0
# Iteration: 7700
# Acceptance ratio beta: 0.3622077922077922
# Acceptance ratio rho: 0.3190909090909091
# Acceptance ratio gamma: 0.36714285714285716
# Acceptance ratio q_r: 0.34285714285714286
# Acceptance ratio q: 0.2766233766233766
# Acceptance ratio eta: 0.0
# Iteration: 7800
# Acceptance ratio beta: 0.3628205128205128
# Acceptance ratio rho: 0.32
# Acceptance ratio gamma: 0.36653846153846154
# Acceptance ratio q_r: 0.34384615384615386
# Acceptance ratio q: 0.27666666666666667
# Acceptance ratio eta: 0.0
# Iteration: 7900
# Acceptance ratio beta: 0.3635443037974683
# Acceptance ratio rho: 0.3220253164556962
# Acceptance ratio gamma: 0.3659493670886076
# Acceptance ratio q_r: 0.34139240506329116
# Acceptance ratio q: 0.27658227848101263
# Acceptance ratio eta: 0.0
# Iteration: 8000
# Acceptance ratio beta: 0.362375
# Acceptance ratio rho: 0.325625
# Acceptance ratio gamma: 0.3655
# Acceptance ratio q_r: 0.338125
# Acceptance ratio q: 0.275375
# Acceptance ratio eta: 0.0
# Iteration: 8100
# Acceptance ratio beta: 0.36148148148148146
# Acceptance ratio rho: 0.3277777777777778
# Acceptance ratio gamma: 0.36518518518518517
# Acceptance ratio q_r: 0.33530864197530863
# Acceptance ratio q: 0.2745679012345679
# Acceptance ratio eta: 0.0
# Iteration: 8200
# Acceptance ratio beta: 0.3619512195121951
# Acceptance ratio rho: 0.3278048780487805
# Acceptance ratio gamma: 0.3647560975609756
# Acceptance ratio q_r: 0.335609756097561
# Acceptance ratio q: 0.276219512195122
# Acceptance ratio eta: 0.0
# Iteration: 8300
# Acceptance ratio beta: 0.3614457831325301
# Acceptance ratio rho: 0.328433734939759
# Acceptance ratio gamma: 0.36493975903614456
# Acceptance ratio q_r: 0.33481927710843373
# Acceptance ratio q: 0.27542168674698797
# Acceptance ratio eta: 0.0
# Iteration: 8400
# Acceptance ratio beta: 0.36095238095238097
# Acceptance ratio rho: 0.3280952380952381
# Acceptance ratio gamma: 0.36547619047619045
# Acceptance ratio q_r: 0.335
# Acceptance ratio q: 0.2760714285714286
# Acceptance ratio eta: 0.0
# Iteration: 8500
# Acceptance ratio beta: 0.3618823529411765
# Acceptance ratio rho: 0.32835294117647057
# Acceptance ratio gamma: 0.3649411764705882
# Acceptance ratio q_r: 0.33494117647058824
# Acceptance ratio q: 0.2767058823529412
# Acceptance ratio eta: 0.0
# Iteration: 8600
# Acceptance ratio beta: 0.36116279069767443
# Acceptance ratio rho: 0.3291860465116279
# Acceptance ratio gamma: 0.36534883720930234
# Acceptance ratio q_r: 0.3338372093023256
# Acceptance ratio q: 0.277093023255814
# Acceptance ratio eta: 0.0
# Iteration: 8700
# Acceptance ratio beta: 0.36160919540229886
# Acceptance ratio rho: 0.3288505747126437
# Acceptance ratio gamma: 0.3664367816091954
# Acceptance ratio q_r: 0.3332183908045977
# Acceptance ratio q: 0.277816091954023
# Acceptance ratio eta: 0.0
# Iteration: 8800
# Acceptance ratio beta: 0.36204545454545456
# Acceptance ratio rho: 0.32897727272727273
# Acceptance ratio gamma: 0.36670454545454545
# Acceptance ratio q_r: 0.33079545454545456
# Acceptance ratio q: 0.2775
# Acceptance ratio eta: 0.0
# Iteration: 8900
# Acceptance ratio beta: 0.36280898876404494
# Acceptance ratio rho: 0.32955056179775283
# Acceptance ratio gamma: 0.36752808988764046
# Acceptance ratio q_r: 0.3313483146067416
# Acceptance ratio q: 0.27876404494382023
# Acceptance ratio eta: 0.0
# Iteration: 9000
# Acceptance ratio beta: 0.36188888888888887
# Acceptance ratio rho: 0.33066666666666666
# Acceptance ratio gamma: 0.36744444444444446
# Acceptance ratio q_r: 0.33011111111111113
# Acceptance ratio q: 0.2782222222222222
# Acceptance ratio eta: 0.0
# Iteration: 9100
# Acceptance ratio beta: 0.3607692307692308
# Acceptance ratio rho: 0.3298901098901099
# Acceptance ratio gamma: 0.36725274725274726
# Acceptance ratio q_r: 0.32978021978021976
# Acceptance ratio q: 0.2774725274725275
# Acceptance ratio eta: 0.0
# Iteration: 9200
# Acceptance ratio beta: 0.3605434782608696
# Acceptance ratio rho: 0.32869565217391306
# Acceptance ratio gamma: 0.3665217391304348
# Acceptance ratio q_r: 0.3293478260869565
# Acceptance ratio q: 0.27706521739130435
# Acceptance ratio eta: 0.0
# Iteration: 9300
# Acceptance ratio beta: 0.3602150537634409
# Acceptance ratio rho: 0.3289247311827957
# Acceptance ratio gamma: 0.3664516129032258
# Acceptance ratio q_r: 0.328494623655914
# Acceptance ratio q: 0.2764516129032258
# Acceptance ratio eta: 0.0
# Iteration: 9400
# Acceptance ratio beta: 0.3604255319148936
# Acceptance ratio rho: 0.32840425531914896
# Acceptance ratio gamma: 0.36606382978723406
# Acceptance ratio q_r: 0.32893617021276594
# Acceptance ratio q: 0.27574468085106385
# Acceptance ratio eta: 0.0
# Iteration: 9500
# Acceptance ratio beta: 0.3606315789473684
# Acceptance ratio rho: 0.3274736842105263
# Acceptance ratio gamma: 0.36694736842105263
# Acceptance ratio q_r: 0.3311578947368421
# Acceptance ratio q: 0.276
# Acceptance ratio eta: 0.0
# Iteration: 9600
# Acceptance ratio beta: 0.36041666666666666
# Acceptance ratio rho: 0.3279166666666667
# Acceptance ratio gamma: 0.36666666666666664
# Acceptance ratio q_r: 0.33166666666666667
# Acceptance ratio q: 0.27677083333333335
# Acceptance ratio eta: 0.0
# Iteration: 9700
# Acceptance ratio beta: 0.36103092783505153
# Acceptance ratio rho: 0.3277319587628866
# Acceptance ratio gamma: 0.3665979381443299
# Acceptance ratio q_r: 0.33103092783505156
# Acceptance ratio q: 0.275979381443299
# Acceptance ratio eta: 0.0
# Iteration: 9800
# Acceptance ratio beta: 0.3603061224489796
# Acceptance ratio rho: 0.32816326530612244
# Acceptance ratio gamma: 0.3666326530612245
# Acceptance ratio q_r: 0.32948979591836736
# Acceptance ratio q: 0.2757142857142857
# Acceptance ratio eta: 0.0
# Iteration: 9900
# Acceptance ratio beta: 0.3609090909090909
# Acceptance ratio rho: 0.3285858585858586
# Acceptance ratio gamma: 0.36737373737373735
# Acceptance ratio q_r: 0.3296969696969697
# Acceptance ratio q: 0.2775757575757576
# Acceptance ratio eta: 0.0

# %% [markdown]
# ### Traceplots, histograms and estimates

# %%
Ebola_data = {}

for k in range(0,1):
    
    Ebola_data[str(k)] = {}
        
    Ebola_data[str(k)]["beta"] = beta_chain
    Ebola_data[str(k)]["rho"]  = q_r_chain
    Ebola_data[str(k)]["gamma"]= rho_chain
    Ebola_data[str(k)]["q_r"]  = gamma_chain
    Ebola_data[str(k)]["q"]    = q_chain

# %%
colors = ["purple", "pink", "orange", "darkgrey", "brown", "darkgreen"] 
labels = [r"$\beta$    ", r"$\lambda$    ", r"$\rho$    ", r"$\gamma$    ", r"$q^{E,I}$        ", r"$q^{I,R}$        "]
keys = ["beta", "q_r", "rho", "gamma", "q"]


fig, ax = plt.subplots(6,2, figsize = (20, 20), dpi =200)

for i in range(0,6): # use 6 for the eta
        
    for j in range(0, 1):
        
        if j==0:
            ax[i,2*j].set_ylabel(labels[i], fontsize=16, rotation =0)
            

        if i<4:
            ax[i,2*j].plot(Ebola_data[str(j)][keys[i]], color = colors[i], linewidth=0.25)
            ax[i,2*j+1].hist(Ebola_data[str(j)][keys[i]], color = colors[i], orientation="horizontal", bins = 20, density =True)
            ax[i,2*j+1].set_yticks([], [])
            ax[i,2*j].xaxis.set_tick_params(labelsize=10)
            ax[i,2*j].yaxis.set_tick_params(labelsize=10)
        else:
            ax[i,2*j].plot(Ebola_data[str(j)][keys[4]][i-3,i-3+1,:], color = colors[i], linewidth=0.25)
            ax[i,2*j+1].hist(Ebola_data[str(j)][keys[4]][i-3,i-3+1,:], color = colors[i], orientation="horizontal", bins = 20, density =True)
            ax[i,2*j+1].set_yticks([], [])
            ax[i,2*j].xaxis.set_tick_params(labelsize=10)
            ax[i,2*j].yaxis.set_tick_params(labelsize=10)

# %%
spaces = ["       ", " ", " ", "         ","   ","   ",]
    
print("MCMC using metropolis within gibbs")
for j in range(0, 1): # use 6 for eta
    string = ""
    for i in range(0, 4):
        string = string + keys[i]+" "+ str(np.round(np.mean(Ebola_data[str(j)][keys[i]]), 3))+" "+ "("+ str(np.round(np.std(Ebola_data[str(j)][keys[i]]),4))+ "); "
    
    string = string + keys[4]+"_12 "+ str(np.round(np.mean(Ebola_data[str(j)][keys[4]][1,2,:]), 3))+ "("+ str(np.round(np.std(Ebola_data[str(j)][keys[4]][1,2,:]),4))+ "); "
    string = string + keys[4]+"_23 "+ str(np.round(np.mean(Ebola_data[str(j)][keys[4]][2,3,:]), 3))+ "("+ str(np.round(np.std(Ebola_data[str(j)][keys[4]][2,3,:]),4))+ "); "
    
    r_0 = Ebola_data[str(j)]["beta"]/Ebola_data[str(j)]["gamma"]
    string = string + "R_0 "+ str(np.round(np.mean(r_0),3)) +"("+str(np.round(np.std(r_0),4))+")" 
    print(string)
# Out:
# MCMC using metropolis within gibbs
# beta 0.372 (0.0569); q_r 0.173 (0.0355); rho 0.337 (0.145); gamma 0.096 (0.0161); q_12 0.442(0.1119); q_23 0.363(0.0952); R_0 3.986(0.934)
